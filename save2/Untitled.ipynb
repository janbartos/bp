# %%
import pandas as pd 
import time
import os
import numpy as np

import datetime
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("out_mod_finished_mod.csv")

# %%
df.Cathegory.unique()
# Out:
# array(['Antidepressants', 'Cars', 'Conspiracy Theories', 'Consumerism',
#        'Contraceptives', 'Crime', 'Education', 'University', 'Emigration',
#        'Entertainment', 'Environmentalism', 'Gambling', 'Games', 'Guns',
#        'Healthcare', 'Housing', 'Charities', 'Ideology', 'Illegal Drugs',
#        'Investing', 'Jobs', 'Legal Drugs', 'Low income', 'Marriage',
#        'News', 'Other', 'Religion', 'S&P 500', 'Sports', 'Stats',
#        'Steroids', 'Tourism'], dtype=object)

# %%
langs = {
    "br" : "PT-BR",
    "us" : "EN",
    "cz" : "CS",
    "de" : "DE",
    "fr" : "FR",
    "nl" : "NL",
    "es" : "ES",
}

# %%
for key in langs:
    df_lang = pd.read_csv("df_data_" + key + ".csv")
    
    for index, row in df_lang.iterrows():
        df_lang.at[ index , 'Cathegory'] = df.loc[df[langs[key]] == row.keyword, "Cathegory"].values[0]
    
    df_lang.to_csv("df_data_" + key + ".csv", encoding='utf-8')

# %%
df_sample_size = pd.read_csv("df_data_cz.csv")
print( str(len(df_sample_size[["Cathegory" == "Cars"]].values)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3628/2454329526.py in <module>
#       1 df_sample_size = pd.read_csv("df_data_cz.csv")
# ----> 2 print( str(len(df_sample_size[["Cathegory" == "Cars"]].values)))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3494             )
#    3495         elif len(key) != len(self.index):
# -> 3496             raise ValueError(
#    3497                 f"Item wrong length {len(key)} instead of {len(self.index)}."
# ...

# %%
df_sample_size[df_sample_size["Cathegory"] == "Cars"]
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1              keyword       2004  \
# 7             7             7               7    prodej automobilů  27.666667
# 8             8             8               8           cena plynu   9.583333
# 9             9             9               9         cena benzínu   5.166667
# 10           10            10              10           cena nafty   3.583333
# 11           11            11              11              leasing  59.583333
# 12           12            12              12        tesla model s  15.916667
# 13           13            13              13        tesla model 3   8.333333
# 14           14            14              14      řidičský průkaz  31.250000
# 15           15            15              15           první auto   0.000000
# 16           16            16              16        mercedes benz  48.083333
# 17           17            17              17                   vw  54.583333
# ...

# %%
df_lang.groupby(by = "Cathegory").mean()
# Out:
#                       Unnamed: 0  Unnamed: 0.1       2004       2005  \
# Cathegory
# Antidepressants       114.448980    114.448980  16.823129  15.739796
# Cars                  150.869565    150.869565  32.601449  31.818841
# Charities             655.800000    655.800000  27.266667  22.886667
# Conspiracy Theories   171.884615    171.884615  16.062500  13.899038
# Consumerism           175.000000    175.000000  15.937500  17.566667
# Contraceptives        250.666667    250.666667  27.250000  20.629630
# Education             209.250000    209.250000  50.283333  46.295833
# Entertainment         440.200787    440.200787  11.705709   9.749016
# Environmentalism      598.333333    598.333333  36.020833  33.006944
# Gambling              535.250000    535.250000  14.234375  14.572917
# Games                 554.642857    554.642857  14.011905  16.291667
# Guns                  561.625000    561.625000  26.473958  21.093750
# ...

# %%
for key in langs:
    df_lang = pd.read_csv("df_data_" + key + ".csv")
    
    df_lang = df_lang.groupby(by = "Cathegory").mean()
    
    df_lang.to_csv("df_data_groupby_" + key + ".csv", encoding='utf-8', index = False)

# %%
for key in langs:
    
    df_lang = pd.read_csv("df_data_groupby_" + key + ".csv")
    

    df_lang = df_lang.drop(['Unnamed: 0', "Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0.1.1.1"], axis = 1)

    df_lang.to_csv("df_data_groupby_" + key + ".csv", encoding='utf-8', index = False)

# %%
df_lang = pd.read_csv("df_data_groupby_" + key + ".csv")
    
    print(df_lang)
# Out:
#   File "C:\Users\Jan\AppData\Local\Temp/ipykernel_9428/2492602818.py", line 3
#     print(df_lang)
#     ^
# IndentationError: unexpected indent

# %%
df_lang.groupby(by = "Cathegory").mean()
# Out:
#                       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# Cathegory
# Antidepressants       114.448980    114.448980      114.448980
# Cars                  150.869565    150.869565      150.869565
# Charities             655.800000    655.800000      655.800000
# Conspiracy Theories   171.884615    171.884615      171.884615
# Consumerism           175.000000    175.000000      175.000000
# Contraceptives        250.666667    250.666667      250.666667
# Education             209.250000    209.250000      209.250000
# Entertainment         440.200787    440.200787      440.200787
# Environmentalism      598.333333    598.333333      598.333333
# Gambling              535.250000    535.250000      535.250000
# Games                 554.642857    554.642857      554.642857
# Guns                  561.625000    561.625000      561.625000
# Healthcare            623.375000    623.375000      623.375000
# Housing               602.250000    602.250000      602.250000
# ...

# %%
for key in langs:
    df_lang = pd.read_csv("df_data_groupby_" + key + ".csv")
    
    df_lang = df_lang.drop(columns = ["Unnamed: 0.1.1.1"])
    
    df_lang.to_csv("df_data_groupby_" + key + ".csv", encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3628/4206765882.py in <module>
#       2     df_lang = pd.read_csv("df_data_groupby_" + key + ".csv")
#       3
# ----> 4     df_lang = df_lang.drop(columns = ["Unnamed: 0.1.1.1"])
#       5
#       6     df_lang.to_csv("df_data_groupby_" + key + ".csv", encoding='utf-8', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
# ...

# %%
df_lang = pd.read_csv("df_data_groupby_fr.csv")

# %%
df_lang
# Out:
#               Cathegory       2004       2005       2006       2007  \
# 0       Antidepressants  17.585317  13.865079  12.174603  10.067460
# 1                  Cars  31.575758  24.617424  22.189394  20.772727
# 2             Charities  25.838889  22.144444  19.066667  16.027778
# 3   Conspiracy Theories  20.485816  14.342199  11.132979   9.787234
# 4           Consumerism  29.870370  26.532407  24.962963  26.625000
# 5        Contraceptives  19.333333  15.740741  13.768519  10.981481
# 6                 Crime  12.083333  19.000000   8.416667   7.416667
# 7             Education  48.384259  42.138889  35.254630  30.879630
# 8         Entertainment  13.036157  10.252410   8.898416   8.510331
# 9      Environmentalism  33.166667  31.111111  29.118056  27.875000
# 10             Gambling  21.901961  19.078431  20.617647  23.519608
# 11                Games  12.705556  17.733333  16.427778  18.250000
# 12                 Guns  23.619792  17.989583  16.302083  15.312500
# ...

# %%
df_lang = pd.read_csv("df_data_br.csv")

# %%
df_lang["Cathegory"].unique()
# Out:
# array(['Antidepressants', 'Cars', 'Conspiracy Theories', 'Consumerism',
#        'Contraceptives', 'Education', 'University', 'Entertainment',
#        'Environmentalism', 'Gambling', 'Games', 'Guns', 'Healthcare',
#        'Housing', 'Charities', 'Ideologies', 'Ideology', 'Illegal Drugs',
#        'Investing', 'Jobs', 'Legal Drugs', 'Low income', 'Marriage',
#        'News', 'Other', 'Religion', 'S&P 500', 'Sports', 'Steroids',
#        'Tourism', 'Stats'], dtype=object)

# %%
for key in langs:
    df_lang = pd.read_csv("df_data_" + key + ".csv")
    print(df_lang["Cathegory"].unique())
# Out:
# ['0    Antidepressants\nName: Cathegory, dtype: object'
#  '1    Antidepressants\nName: Cathegory, dtype: object'
#  '2    Antidepressants\nName: Cathegory, dtype: object' ...
#  '1848    Steroids\nName: Cathegory, dtype: object'
#  '1958    Tourism\nName: Cathegory, dtype: object'
#  '1969    Tourism\nName: Cathegory, dtype: object']
# ['0    Antidepressants\nName: Cathegory, dtype: object'
#  '1    Antidepressants\nName: Cathegory, dtype: object'
#  '2    Antidepressants\nName: Cathegory, dtype: object' ...
#  '1938    Tourism\nName: Cathegory, dtype: object'
#  '1955    Tourism\nName: Cathegory, dtype: object'
#  '1970    Tourism\nName: Cathegory, dtype: object']
# ['3    Antidepressants\nName: Cathegory, dtype: object'
#  '14    Antidepressants\nName: Cathegory, dtype: object'
#  '19    Antidepressants\nName: Cathegory, dtype: object' ...
#  '1905    Tourism\nName: Cathegory, dtype: object'
#  '220    Education\nName: Cathegory, dtype: object'
# ...

# %%
df_lang.groupby(["Cathegory"]).mean()
# Out:
#                       Unnamed: 0  Unnamed: 0.1       2004       2005  \
# Cathegory
# Antidepressants       103.285714    103.285714  17.717262  14.897321
# Cars                  186.857143    186.857143  23.873016  20.650794
# Charities             643.240000    643.240000  22.976667  22.903333
# Conspiracy Theories   184.260000    184.260000  20.160000  16.445000
# Consumerism           189.500000    189.500000  20.844697  16.696970
# Contraceptives        138.000000    138.000000  30.851852  26.444444
# Crime                 379.333333    379.333333  21.194444   5.527778
# Education             235.454545    235.454545  57.579545  50.946970
# Entertainment         427.817308    427.817308  13.044872  11.582532
# Entertainment\n732    323.000000    323.000000  13.833333  13.333333
# Environmentalism      512.583333    512.583333  27.472222  25.048611
# Gambling              534.437500    534.437500  13.869792  12.359375
# ...

# %%
df1 = pd.DataFrame(columns=["cathegory","2004", "2005", "2006", "2007", "2008" ,"2009", "2010", "2011", "2012" , "2013", "2014", "2015", "2016", "2017" ,"2018" ,"2019" ,"2020" ,"2021"])

# %%
df["Cathegory"] = df.Cathegory.unique()
df1 = df1.fillna(0)

# %%
df_lang
# Out:
#                          keyword       2004       2005       2006       2007  \
# 0                        Adaptar  52.083333  46.083333  34.500000  42.916667
# 1                        doxepin   0.000000  23.000000  11.916667   8.000000
# 2                      Anafranil  31.666667  14.666667  22.916667  12.416667
# 3                   clomipramina  15.083333  10.500000   9.583333   9.583333
# 4                     bupropiona  19.083333  15.750000  25.416667  19.750000
# ...                          ...        ...        ...        ...        ...
# 1250                      Vettel  12.583333   3.666667   0.416667   2.416667
# 1251  Propionato de drostanolona  13.666667   3.583333   1.416667   0.583333
# 1252       Acetato de metenolona   0.000000  11.166667  15.750000   1.416667
# 1253                    reservas  77.750000  63.333333  48.833333  44.666667
# 1254                 ultra miami  21.916667   9.250000   9.083333   5.416667
#
# ...

# %%
df_lang["Cathegory"].dtype
# Out:
# dtype('float64')

# %%
count = np.zeros(df.Cathegory.unique().size)
sums = np.zeros(df.Cathegory.unique().size)

for index, row in df_lang.iterrows():

    s = df.loc[df['PT-BR'] == row.keyword]['Cathegory']
    s = s.to_string()
    s = s.split("    ")[1]
    #index = np.where(df.Cathegory.unique() == s)
    print(s, row.keyword)
    print(df_lang.at[ index , 'Cathegory'])
    df_lang.at[ index , 'Cathegory'] = s

# %%
count = np.zeros(df.Cathegory.unique().size)
sums = np.zeros(df.Cathegory.unique().size)

for index, row in df_lang.iterrows():

    s = df.loc[df['PT-BR'] == row.Keyword]['Cathegory']
    s = s.to_string()
    s = s.split("    ")[1]
    index = np.where(df.Cathegory.unique() == s)
    print(s)
    count[index] += 1
    sums[index] += row.fertility

# %%
df_lang
# Out:
#                          keyword       2004       2005       2006       2007  \
# 0                        Adaptar  52.083333  46.083333  34.500000  42.916667
# 1                        doxepin   0.000000  23.000000  11.916667   8.000000
# 2                      Anafranil  31.666667  14.666667  22.916667  12.416667
# 3                   clomipramina  15.083333  10.500000   9.583333   9.583333
# 4                     bupropiona  19.083333  15.750000  25.416667  19.750000
# ...                          ...        ...        ...        ...        ...
# 1250                      Vettel  12.583333   3.666667   0.416667   2.416667
# 1251  Propionato de drostanolona  13.666667   3.583333   1.416667   0.583333
# 1252       Acetato de metenolona   0.000000  11.166667  15.750000   1.416667
# 1253                    reservas  77.750000  63.333333  48.833333  44.666667
# 1254                 ultra miami  21.916667   9.250000   9.083333   5.416667
#
# ...

# %%
df[243:500]
# Out:
#      Unnamed: 0                                  EN  Flag   Cathegory  \
# 243         248             University of Cambridge     1  University
# 244         249  California Institute of Technology     1  University
# 245         250                             Caltech     1  University
# 246         251            University of California     1  University
# 247         252                            Berkeley     1  University
# ..          ...                                 ...   ...         ...
# 495         505                     RMIT University     1  University
# 496         506                    Korea University     1  University
# 497         507       Tokyo Institute of Technology     1  University
# 498         508                          Tokyo Tech     1  University
# 499         509                 University of Otago     1  University
#
#      Keyword_Count                                  CS  \
# 243             23              Univerzita v Cambridge
# ...

# %%
# Out:
#                                       Keyword  Flag   Cathegory  \
# 243                        Harvard University     1  University
# 244     Massachusetts Institute of Technology     1  University
# 245                                       MIT     1  University
# 246                       Stanford University     1  University
# 247                      University of Oxford     1  University
# ..                                        ...   ...         ...
# 543          École Normale Supérieure de Lyon     1  University
# 544                               ENS de Lyon     1  University
# 545  Pontificia Universidad Católica de Chile     1  University
# 546   Pontifical Catholic University of Chile     1  University
# 547                         Kyushu University     1  University
#
#      Keyword_Count                                      CS  \
# 243             18                   Harvardova univerzita
# 244             37  Massachusettský technologický institut
# ...

# %%
df.to_csv('out_mod_finished.csv', encoding='utf-8')

# %%
df.rename(columns={'Keyword': 'EN'}, inplace=True)

# %%
df['Cathegory'] = df['Cathegory'].str.replace('Conspiracy theories', 'Conspiracy Theories')

# %%
df_br = pd.read_csv("df_data_br_corr.csv")

# %%
df_br.rename(columns={'Unnamed: 0': 'Keyword'}, inplace=True)

# %%
df_br
# Out:
#                          Keyword  fertility
# 0                        Adaptar  -0.748569
# 1                        doxepin   0.603078
# 2                      Anafranil   0.812812
# 3                   clomipramina  -0.030566
# 4                     bupropiona  -0.817642
# ...                          ...        ...
# 1251  Propionato de drostanolona   0.747130
# 1252       Acetato de metenolona   0.559879
# 1253                    reservas   0.801644
# 1254                 ultra miami   0.328252
# 1255                   fertility   1.000000
#
# [1256 rows x 2 columns]

# %%
df.Cathegory.unique()
# Out:
# array(['Antidepressants', 'Cars', 'Conspiracy Theories', 'Consumerism',
#        'Contraceptives', 'Crime', 'Education', 'University', 'Emigration',
#        'Entertainment', 'Environmentalism', 'Gambling', 'Games', 'Guns',
#        'Healthcare', 'Housing', 'Charities', 'Ideologies', 'Ideology',
#        'Illegal Drugs', 'Investing', 'Jobs', 'Legal Drugs', 'Low income',
#        'Marriage', 'News', 'Other', 'Religion', 'S&P 500', 'Sports',
#        'Stats', 'Steroids', 'Tourism'], dtype=object)

# %%
df_us
# Out:
#                    keyword  fertility
# 0                   Adapin   0.775458
# 1                  doxepin  -0.926735
# 2                Anafranil   0.864376
# 3             clomipramine   0.326592
# 4                bupropion  -0.965132
# ...                    ...        ...
# 1812  Acadia national park  -0.633288
# 1813               flights  -0.851897
# 1814             coachella  -0.724415
# 1815             fertility   1.000000
# 1816                  corr        NaN
#
# [1817 rows x 2 columns]

# %%
df = df.drop_duplicates()

# %%
#count = []
#sums = []

count = np.zeros(df.Cathegory.unique().size)
sums = np.zeros(df.Cathegory.unique().size)

for index, row in df_br.iterrows():

    s = df.loc[df['PT-BR'] == row.Keyword]['Cathegory']
    s = s.to_string()
    s = s.split("    ")[1]
    index = np.where(df.Cathegory.unique() == s)
    print(s)
    count[index] += 1
    sums[index] += row.fertility
# Out:
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Antidepressants
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# Cars
# ...

# %%
print(count)
# Out:
# [ 56.  21.  50.  22.   9.   3.  22. 107.   0. 208.  12.  16.  10.  16.
#   33.  13.  25.   4.  26.  24.  16.  11.  28.   9.   5.  56.   4.  35.
#  324.  13.   2.  16.  52.]

# %%
print(sums)
# Out:
# [ 19.25533913   5.31898244  13.62384338   1.78561119   3.82072365
#    2.5068315   15.01296263  76.5326351    0.          27.23008841
#    5.21049374   1.48295944  -1.83526286   1.22487214  12.22145809
#    2.26529046  13.50566711   1.76174537  14.65831789   6.48426234
#    2.73647974   5.62515789   7.23122172   2.34546074   3.41742272
#   28.43883316   2.68239258  12.31258698 179.8566039    0.59361487
#    1.45649784   3.50137082  16.25154906]

# %%
avg = np.zeros(count.size)

for x in range(count.size):
    if count[x] != 0:
        avg[x] = sums[x] / count[x]

# %%
print(avg)
# Out:
# [ 0.34384534  0.25328488  0.27247687  0.08116415  0.42452485  0.8356105
#   0.68240739  0.71525827  0.          0.13091389  0.43420781  0.09268497
#  -0.18352629  0.07655451  0.37034721  0.17425311  0.54022668  0.44043634
#   0.56378146  0.2701776   0.17102998  0.51137799  0.25825792  0.26060675
#   0.68348454  0.50783631  0.67059815  0.3517882   0.55511297  0.04566268
#   0.72824892  0.21883568  0.31252979]

# %%
for index, row in df_br.iterrows():
   
    s = df.loc[df['PT-BR'] == row.Keyword]
    if s['Cathegory'].values[0] == 'Crime':
        print(s)
    #if s["Cathegory"] == "Crime":
     #   print(s)
# Out:
#                   EN  Flag Cathegory  Keyword_Count                CS  \
# 212  School shooting     1     Crime             15  Střelba ve škole
#
#                            DE                     ES             PT-BR  \
# 212  Schießerei in der Schule  Tiroteo en la escuela  Tiroteio escolar
#
#                            FR                      NL
# 212  Fusillade dans une école  Schietpartij op school
#                 EN  Flag Cathegory  Keyword_Count              CS  \
# 213  School police     1     Crime             13  Školní policie
#
#                DE               ES            PT-BR               FR  \
# 213  Schulpolizei  Policía escolar  Polícia escolar  Police scolaire
#
#                 NL
# 213  Schoolpolitie
#           EN  Flag Cathegory  Keyword_Count                         CS  \
# 211  fake id     1     Crime              7  falešný průkaz totožnosti
#
#                       DE                    ES                PT-BR  \
# ...

# %%
my_pd=pd.DataFrame(data=df.Cathegory.unique(),columns=['Cathegory'])
my_pd['Corr'] = avg
my_pd['Count'] = count

# %%
my_pd.to_csv('data_us_cathegories_corr.csv', encoding='utf-8')

# %%
my_pd
# Out:
#               Cathegory      Corr  Count
# 0       Antidepressants  0.343845   56.0
# 1                  Cars  0.253285   21.0
# 2   Conspiracy Theories  0.272477   50.0
# 3           Consumerism  0.081164   22.0
# 4        Contraceptives  0.424525    9.0
# 5                 Crime  0.835611    3.0
# 6             Education  0.682407   22.0
# 7            University  0.715258  107.0
# 8            Emigration  0.000000    0.0
# 9         Entertainment  0.130914  208.0
# 10     Environmentalism  0.434208   12.0
# 11             Gambling  0.092685   16.0
# 12                Games -0.183526   10.0
# 13                 Guns  0.076555   16.0
# 14           Healthcare  0.370347   33.0
# 15              Housing  0.174253   13.0
# 16            Charities  0.540227   25.0
# 17           Ideologies  0.440436    4.0
# 18             Ideology  0.563781   26.0
# 19        Illegal Drugs  0.270178   24.0
# 20            Investing  0.171030   16.0
# 21                 Jobs  0.511378   11.0
# ...
